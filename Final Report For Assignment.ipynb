# %% [markdown]
# # Peer-graded Assignment: Capstone Project - The Battle of Neighborhoods (Week 2)

# %% [markdown]
# ## Section 1: Introduction
# #### Introduction where you discuss the business problem and who would be interested in this project.
#
# ##### I think the people who would be interested in this project can includes the people who plan to move to the new place. Since when people move to the new city, country or state. They want to find an efficiency way to explore better facilities around their neighborhood, based on the information provide from data analysis (this project), it can help them to make a samrt decision in an efficiency way.
#
# ##### In addition, many people are moving to Canada, and they need to know the price of housing, the find the reputated schools for their children, and do some research for ease of accessing to Cafe, School, Super market, medical shops, grocery shops, mall, theatre, hospital, and so on. This project can also help them to find the better neighborhoods based on the things they considered.
#
# ##### Morever, if people need to start any new business, this project can also help them to get together all the necessary information, such as the pricing, the population and stores, etc around their neighborhood.
#
# ##### It can help people to make decision before they start their new life. In my project, I want to show people how this project can help people to find a better place in Scarborough, Toronto as an example.(People can use different data as needed.)

# %% [markdown]
# ## Section 2: Data
# #### where you describe the data that will be used to solve the problem and the source of the data
#
# ##### The data will use in the project shows as link here: https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M;
# ##### Also, the project will includes the Scarborough data such as the latitude, longitude as well as the zip codes for each area.
#
# #### Subsection 2.1： Foursquare API Data
# ##### We will need data about different venues in different neighborhoods of that specific borough. In order to gain that information we will use "Foursquare" locational information.
# ##### The reason why we need to use Foursquare API is because, it is a location data provider with information about all manner of venues and events within an area of interest.
# ##### Those information includes venue names, locations, menus and even photos. Therefore, the foursquare location platform will be used as the sole data source since all the stated required information can be obtained through the API.
#
#
# <dl>
# <dt>After finding the list of neighborhoods we need, we will use the Foursquare API to gather information about venues inside each and every neighborhood.</dt>
# <dt>In addition, for each neighborhood, we have chosen the radius to be 100 meter just for this project, you can use whatever you need for analysis</dt>
# <dt>There are totoal 8 information use for each venues as follow:.</dt>
# <dd>1. Neighborhood.</dd>
# <dd>2. Neighborhood Latitude.</dd>
# <dd>3. Neighborhood Longitude.</dd>
# <dd>4. Name.</dd>
# <dd>5. Name of the venue.</dd>
# <dd>6. Venue Latitude.</dd>
# <dd>7. Venue Longitude.</dd>
# <dd>8. Venue Latitude.</dd>
# </dl>
#
#
# #### Subsection 2.2： Map of Scarborough (we can find it in the NoteBook: Final Assignment with all the code and output)

# %% [markdown]
# ![Capture.PNG](attachment:4c013049-f977-4273-bff0-c2f53ddb6405.PNG)

# %% [markdown]
# #### Subsection 2.3：Shows the'venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng'
# ##### We can see there are Sephora, Diseny Store, American Eagle Store, Fish&Chip and Tommy Hilfiger nearby

# %% [markdown]
# ![Capture.PNG](attachment:d5bc406c-1ba3-4a80-853b-0844fffd442b.PNG)

# %% [markdown]
# ## Section 3: Methodology section
# #### Methodology section which represents the main component of the report where you discuss and describe any exploratory data analysis that you did, any inferential statistical testing that you performed, if any, and what machine learnings were used and why.

# %% [markdown]
# #### Clustering Approach:
# ##### To compare the similarities of two cities, we decided to explore neighborhoods, segment them, and group them into clusters to find similar neighborhoods in a big city like New York and Toronto. To be able to do that, we need to cluster data which is a form of unsupervised machine learning: k-means clustering algorithm.

# %% [markdown]
# ##### Section 3.1 K-Mean (10 top venues were been pick to use)
# ![Capture.PNG](attachment:7f5c97d3-af66-4f43-b492-e0ef88e54c05.PNG)

# %% [markdown]
# ##### Using K-Means to cluster neighborhood into 3 clusters
# ![Capture.PNG](attachment:0e5c17fd-c499-4fd0-a7f5-b95782af44a2.PNG)

# %% [markdown]
# ##### 10 most popular venues
# ![Capture.PNG](attachment:bf16662d-ee58-4212-b199-30e5736aea95.PNG)

# %% [markdown]
# ## Section 4: Results section
# #### Results section where you discuss the results.

# %% [markdown]
# ##### By using the kclusters = 10, we can find the 10 place mark in the map
# ![Capture.PNG](attachment:d91926d8-6f88-4c7e-adbb-c7423846f944.PNG)
#
# ##### Map shows in the belows:
# ![Capture.PNG](attachment:acfb3d53-0aaf-41ac-9a4e-42dc96454c3a.PNG)

# %% [markdown]
# #### By using the data about pricing nearby, we can find the average price for housing below: (If the picture hard to see, please check it in the code I upload)
# ![Capture.PNG](attachment:bcbedd8a-727d-4e65-a9bb-b93f4b44a841.PNG)

# %% [markdown]
# #### School Ratings by Clusters in Scarborough
# ![Capture.PNG](attachment:c52e0975-6637-4bab-97e7-084e55cd0a94.PNG)

# %% [markdown]
# #### From all the results shows above, we can see that Scarborough is a popular destination for new immigrants in Canada to reside. Also, it is one of the most diverse and multicultural areas in the Greater Toronto Area, being home to various religious groups and places of worship. We can said that immigration still the hot trend for recent years.

# %% [markdown]
# ## Section 5: Discussion section
# #### where you discuss any observations you noted and any recommendations you can make based on the results.

# %% [markdown]
# ##### As I said in the begining of this report, we know this project is to help people who plan to start their new life at Canada. And this project is based on the pricing of the house, the reputation of nearby school and poluation to help people know the certain conditions they need to know before they make decision to move;
#
# ##### In addition, this project may apply to the people who have middle/normal level of income, they have certain income to support their life, but for the people who really rich or poor, may need to have different database to do the analysis based on their needs and condidtions.

# %% [markdown]
# ## Section 6: Conclusion
# #### Conclusion section where you conclude the report.

# %% [markdown]
# #### In this project, we using k-means cluster algorithm, and I pick k=10 which means we separate all the neighborhood into 10different clusters and for 103 different lattitude and logitude from dataset, which have very-similar neighborhoods around them.
#
# #### As the results shows in above, we provides the average house prices and school rating to help them make better decision.
#
# #### I use the most important contain I learn during the course into this project, such as the mapping, k-mean algorith, API and so on, to help me to do a better analysis. Also, the analysis become more efficiency by using all the knowledges. This project has shown me a practical application to resolve a real situation that has impacting personal and financial impact using Data Science tools. The mapping is a very powerful way to show the result and better way to visual the results.
#
# #### In the future, people can improve this project by addition more data to help the analysis more rich and efficiency. And can apply to different situiations.
